# %% [markdown]
# #                                      E-Surveillance Alert Classification

# %% [markdown]
# # Business Problem

# %% [markdown]
# Description:
#
# Prevent break-ins before they occur using IoT security cameras with built-in computer vision capabilities, reducing the need for human intervention. Automated security to safeguard and alert against threats from intrusion or fire using multi-capability sensors such as vibration, motion, smoke, fire, etc.  Ensure the safety of both monetary and intellectual assets with round-the-clock surveillance and controlled access management.

# %% [markdown]
# # Problem Statement

# %% [markdown]
# We are tasked with classifying the alert  whether it is Critical, Normal, or Testing which is received from the various sensors. Such as vibration, motion, smoke, fire.

# %% [markdown]
# # Real world/Business Objectives and Constraints

# %% [markdown]
# 1.The cost of a mis-classification can be very high.
#
# 2.No strict latency concerns.

# %% [markdown]
# # Mapping the real world problem to an ML problem

# %% [markdown]
# # Type of Machine Leaning Problem

# %% [markdown]
# Supervised Learning:
#
# It is a Multi classification problem, for a given sensor data we need to classify if it is critical, Normal, or Testing

# %% [markdown]
# # Train and Test Construction

# %% [markdown]
# We build train and test by randomly splitting in the ratio of 70:30 or 80:20 whatever we choose as we have sufficient points to work with.

# %% [markdown]
# # Importing Necessary Libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import rcParams
from matplotlib.cm import rainbow
# %matplotlib inline
import warnings

warnings.filterwarnings('ignore')

# %% [markdown]
# # Data

# %%
data= pd.read_csv('Master - Ack Time Analysis From April-20 to August-20 - Details.csv',error_bad_lines= False)
data
# Out:
#              DATE SOL ID                               Branch  \
# 0        1-Apr-20   6358            MH_6358_Vasant Rutu Plaza
# 1        1-Apr-20   6116               TN_6116_Ramanathapuram
# 2        1-Apr-20   4407              AP_4407_Pandurangapuram
# 3        1-Apr-20   6973             MH_OPX_6973_Ichalkaranji
# 4        1-Apr-20   0066       PJ_0066_Amritsar_Lawrence Road
# 5        1-Apr-20   1453                 MH_OPX_1453_Malkapur
# 6        1-Apr-20   2314          UP_OPX_2314_Transport_Nagar
# 7        1-Apr-20   4057                       MH_4057_Mehkar
# 8        1-Apr-20   0233                  HR_0233_Ambala_City
# 9        1-Apr-20   0233                  HR_0233_Ambala_City
# 10       1-Apr-20   ICMC           AP_ICMC_Vizag_Ground_Floor
# 11       1-Apr-20   1107                   MH_OPX_1107_Udhgir
# 12       1-Apr-20   0181                       KL_0181_Kannur
# 13       1-Apr-20   6065                   TN_OPX_6065_Kallal
# 14       1-Apr-20   0181                       KL_0181_Kannur
# 15       1-Apr-20   0633                    JH_OPX_0633_Gumla
# 16       1-Apr-20   7396          MH_7396_Katraj_Kondhwa_Road
# 17       1-Apr-20   0273       PJ_0273_Jalandhar_Adarsh Nagar
# 18       1-Apr-20   4062                      MP_4062_Rajgarh
# 19       1-Apr-20   2556  BR_OPX_2556_Barauni_Mirchaiya_Chauk
# 20       1-Apr-20   0633                    JH_OPX_0633_Gumla
# 21       1-Apr-20   3951                   AP_3951_Markapuram
# 22       1-Apr-20   2556  BR_OPX_2556_Barauni_Mirchaiya_Chauk
# 23       1-Apr-20   0162       PJ_0162_Patiala_chottibaradari
# 24       1-Apr-20   1979                     AP_OPX_1979_Tuni
# 25       1-Apr-20   1979                     AP_OPX_1979_Tuni
# 26       1-Apr-20   6065                   TN_OPX_6065_Kallal
# 27       1-Apr-20   7522                       GJ_7522_Bherai
# 28       1-Apr-20   6394                  MH_OPX_6394_Tasgaon
# 29       1-Apr-20   1740                    GJ_1740_Changodar
# ...           ...    ...                                  ...
# 185657  30-Sep-20   2177             AH_RJ_OPX_2177_Army Area
# 185658  30-Sep-20   2177             AH_RJ_OPX_2177_Army Area
# 185659  30-Sep-20   2177             AH_RJ_OPX_2177_Army Area
# 185660  30-Sep-20   2177             AH_RJ_OPX_2177_Army Area
# 185661  30-Sep-20   2177             AH_RJ_OPX_2177_Army Area
# 185662  30-Sep-20   2177             AH_RJ_OPX_2177_Army Area
# 185663  30-Sep-20   2797                OR_OPX_2797_Baramunda
# 185664  30-Sep-20   2797                OR_OPX_2797_Baramunda
# 185665  30-Sep-20   2797                OR_OPX_2797_Baramunda
# 185666  30-Sep-20   1400          HR_1400_Faridabad_Sector_19
# 185667  30-Sep-20   2177             AH_RJ_OPX_2177_Army Area
# 185668  30-Sep-20   3045                 OR_OPX_3045_Karanjia
# 185669  30-Sep-20   3045                 OR_OPX_3045_Karanjia
# 185670  30-Sep-20   3045                 OR_OPX_3045_Karanjia
# 185671  30-Sep-20   7207                     RJ_7207_Sitabari
# 185672  30-Sep-20   7207                     RJ_7207_Sitabari
# 185673  30-Sep-20   2177             AH_RJ_OPX_2177_Army Area
# 185674  30-Sep-20   2177             AH_RJ_OPX_2177_Army Area
# 185675  30-Sep-20   6656              RJ_OPX_6656_Bachh_Khera
# 185676  30-Sep-20   6656              RJ_OPX_6656_Bachh_Khera
# 185677  30-Sep-20   6656              RJ_OPX_6656_Bachh_Khera
# 185678  30-Sep-20   7247                       GJ_7247_Saroli
# 185679  30-Sep-20   7247                       GJ_7247_Saroli
# 185680  30-Sep-20   6707              RJ_6707_Sri Ganga Nagar
# 185681  30-Sep-20   6707              RJ_6707_Sri Ganga Nagar
# 185682  30-Sep-20   6707              RJ_6707_Sri Ganga Nagar
# 185683  30-Sep-20   6707              RJ_6707_Sri Ganga Nagar
# 185684  30-Sep-20   2797                OR_OPX_2797_Baramunda
# 185685  30-Sep-20   2797                OR_OPX_2797_Baramunda
# 185686  30-Sep-20   2797                OR_OPX_2797_Baramunda
#
#                      SENSOR (As of Portal) Region           STATE  \
# 0                                   System   West     Maharashtra
# 1                 PIR - Inside Strong Room  South              TN
# 2                                   System  South  Andhra Pradesh
# 3                                   System   West     Maharashtra
# 4                                   System  North          Punjab
# 5              Vibration Sensor - S1CNP588   West     Maharashtra
# 6                                   System  North              UP
# 7                                   System   West     Maharashtra
# 8                PIR - Outside Strong Room  North         Haryana
# 9                                   Hooter  North         Haryana
# 10            Door Sensor - Main Shutter 2  South  Andhra Pradesh
# 11                                  System   West     Maharashtra
# 12                Vibration Sensor - ATM 2  South          Kerala
# 13          Shutter Sensor - Front Shutter  South              TN
# 14                Vibration Sensor - ATM 2  South          Kerala
# 15      Vibration Sensor - ATM ID S1CNP358  North       Jharkhand
# 16                                  System   West     Maharashtra
# 17               PIR - Outside Strong Room  North          Punjab
# 18                                  System   West              MP
# 19               PIR - Outside Strong Room  North           Bihar
# 20      Vibration Sensor - ATM ID S1CNP358  North       Jharkhand
# 21                                  System  South  Andhra Pradesh
# 22               PIR - Outside Strong Room  North           Bihar
# 23                                  System  North          Punjab
# 24               PIR - Outside Strong Room  South  Andhra Pradesh
# 25                                  Hooter  South  Andhra Pradesh
# 26          Shutter Sensor - Front Shutter  South              TN
# 27                                  System   West         Gujarat
# 28                                  Hooter   West     Maharashtra
# 29               PIR - Outside Strong Room   West         Gujarat
# ...                                    ...    ...             ...
# 185657            Smoke Sensor - ATM Lobby   West       Rajasthan
# 185658                              Hooter   West       Rajasthan
# 185659                  Panic - Stop Panic   West       Rajasthan
# 185660                              Hooter   West       Rajasthan
# 185661                              Hooter   West       Rajasthan
# 185662                  Panic - Stop Panic   West       Rajasthan
# 185663              Smoke Sensor - BM Room   East          Orissa
# 185664                              Hooter   East          Orissa
# 185665                  Panic - Stop Panic   East          Orissa
# 185666                  Panic - Stop Panic  North         Haryana
# 185667                              Hooter   West       Rajasthan
# 185668                    Panic - ATM Room   East          Orissa
# 185669                              Hooter   East          Orissa
# 185670                  Panic - Stop Panic   East          Orissa
# 185671                              Hooter   West       Rajasthan
# 185672                  Panic - Stop Panic   West       Rajasthan
# 185673                    Panic - ATM Room   West       Rajasthan
# 185674                  Panic - Stop Panic   West       Rajasthan
# 185675                    Panic - DBM Desk   West       Rajasthan
# 185676                              Hooter   West       Rajasthan
# 185677                  Panic - Stop Panic   West       Rajasthan
# 185678                              Hooter   West         Gujarat
# 185679                  Panic - Stop panic   West         Gujarat
# 185680                    Hooter - OutSide   West       Rajasthan
# 185681                  Panic - Front Desk   West       Rajasthan
# 185682                     Hooter - Inside   West       Rajasthan
# 185683                  Panic - Stop Panic   West       Rajasthan
# 185684            Smoke Sensor - ATM Lobby   East          Orissa
# 185685                              Hooter   East          Orissa
# 185686                  Panic - Stop Panic   East          Orissa
#
#        SENSOR NAME (Standard)                            EVENT  \
# 0                     Network      Network communication error
# 1                         PIR  PIR Motion Detected Armed Hours
# 2                     Network      Network communication error
# 3                     Network      Network communication error
# 4                     Network      Network communication error
# 5                   Vibration               Vibration Detected
# 6                     Network      Network communication error
# 7                     Network      Network communication error
# 8                         PIR  PIR Motion Detected Armed Hours
# 9                      Hooter                        Hooter ON
# 10              Front Shutter          Open during Armed Hours
# 11                    Network      Network communication error
# 12                  Vibration               Vibration Detected
# 13              Front Shutter          Open during Armed Hours
# 14                  Vibration               Vibration Detected
# 15                  Vibration               Vibration Detected
# 16                    Network      Network communication error
# 17                        PIR  PIR Motion Detected Armed Hours
# 18                    Network      Network communication error
# 19                        PIR  PIR Motion Detected Armed Hours
# 20                  Vibration               Vibration Detected
# 21                    Network      Network communication error
# 22                        PIR  PIR Motion Detected Armed Hours
# 23                    Network      Network communication error
# 24                        PIR  PIR Motion Detected Armed Hours
# 25                     Hooter                        Hooter ON
# 26              Front Shutter          Open during Armed Hours
# 27                    Network      Network communication error
# 28                     Hooter                        Hooter ON
# 29                        PIR  PIR Motion Detected Armed Hours
# ...                       ...                              ...
# 185657                  Smoke                      Smoke Alarm
# 185658                 Hooter                        Hooter ON
# 185659            Stop Panic                  Stop Panic Alarm
# 185660                 Hooter                        Hooter ON
# 185661                 Hooter                        Hooter ON
# 185662            Stop Panic                  Stop Panic Alarm
# 185663                  Smoke                      Smoke Alarm
# 185664                 Hooter                        Hooter ON
# 185665            Stop Panic                  Stop Panic Alarm
# 185666            Stop Panic                  Stop Panic Alarm
# 185667                 Hooter                        Hooter ON
# 185668                  Panic                      Panic Alarm
# 185669                 Hooter                        Hooter ON
# 185670            Stop Panic                  Stop Panic Alarm
# 185671                 Hooter                        Hooter ON
# 185672            Stop Panic                  Stop Panic Alarm
# 185673                  Panic                      Panic Alarm
# 185674            Stop Panic                  Stop Panic Alarm
# 185675                  Panic                      Panic Alarm
# 185676                 Hooter                        Hooter ON
# 185677            Stop Panic                  Stop Panic Alarm
# 185678                 Hooter                        Hooter ON
# 185679            Stop Panic                  Stop Panic Alarm
# 185680                 Hooter                        Hooter ON
# 185681                  Panic                      Panic Alarm
# 185682                 Hooter                        Hooter ON
# 185683            Stop Panic                  Stop Panic Alarm
# 185684                  Smoke                      Smoke Alarm
# 185685                 Hooter                        Hooter ON
# 185686            Stop Panic                  Stop Panic Alarm
#
#        EVENT DATE AND TIME                                  AKNOWLEDGE STATUS  \
# 0              4/1/20 0:07  True Alarm - Confirmed via Portal & Escalated ...
# 1              4/1/20 0:11  \nFalse_False_Alarm - Branch Closed,  Verified...
# 2              4/1/20 0:15  True Alarm - Confirmed via Portal & Escalated ...
# 3              4/1/20 0:27  True Alarm - Confirmed via Portal & Escalated ...
# 4              4/1/20 0:46  True Alarm - Confirmed via Portal & Escalated ...
# 5              4/1/20 0:47              False_False_Alarm - Verified via CCTV
# 6              4/1/20 0:51  True Alarm - Confirmed via Portal & Escalated ...
# 7              4/1/20 1:04  True Alarm - Confirmed via Portal & Escalated ...
# 8              4/1/20 1:05  False_False_Alarm - Branch Closed, Confirmed v...
# 9              4/1/20 1:05  False_False_Alarm - Branch Closed, Confirmed v...
# 10             4/1/20 1:14  False_False_Alarm - Branch Closed, Confirmed v...
# 11             4/1/20 1:40   True Alarm - Confirmed via Portal & Escalated...
# 12             4/1/20 1:43       False_False_Alarm - Confirmed with security.
# 13             4/1/20 2:06  False_False_Alarm - Branch Closed,  Verified C...
# 14             4/1/20 2:14      False_False_Alarm - Confirmed with security.
# 15             4/1/20 2:28                False_False_Alarm - Verified CCTV.
# 16             4/1/20 2:28   True Alarm - Confirmed via Portal & Escalated...
# 17             4/1/20 2:36  False_False_Alarm - Branch Closed, . VerifiedT...
# 18             4/1/20 3:02   True Alarm - Confirmed via Portal & Escalated...
# 19             4/1/20 3:04  False_False_Alarm - Branch Closed, Confirmed v...
# 20             4/1/20 3:08                False_False_Alarm - Verified CCTV.
# 21             4/1/20 3:08   True Alarm - Confirmed via Portal & Escalated...
# 22             4/1/20 3:34  False_False_Alarm - Branch Closed, Confirmed v...
# 23             4/1/20 3:41   True Alarm - Confirmed via Portal & Escalated...
# 24             4/1/20 3:49  False_False_Alarm - Branch Closed, Confirmed v...
# 25             4/1/20 3:49  False_False_Alarm - Branch Closed, Confirmed v...
# 26             4/1/20 4:23  False_False_Alarm - Branch Closed, Verified CC...
# 27             4/1/20 4:28   True Alarm - Confirmed via Portal & Escalated...
# 28             4/1/20 4:56  False_False_Alarm - Branch Closed, Confirmed w...
# 29             4/1/20 5:07  False_False_Alarm - Branch Closed, Confirmed w...
# ...                    ...                                                ...
# 185657       9/30/20 13:43   Testing_Alarm - Confirmed with BM, Testing by...
# 185658       9/30/20 13:43   Testing_Alarm - Confirmed with BM, Testing by...
# 185659       9/30/20 13:43   Testing_Alarm - Confirmed with BM, Testing by...
# 185660       9/30/20 13:43   Testing_Alarm - Confirmed with BM, Testing by...
# 185661       9/30/20 13:44   Testing_Alarm - Confirmed with BM, Testing by...
# 185662       9/30/20 13:44   Testing_Alarm - Confirmed with BM, Testing by...
# 185663       9/30/20 13:45   Testing_Alarm - Confirmed with DBM, Testing b...
# 185664       9/30/20 13:45   Testing_Alarm - Confirmed with DBM, Testing b...
# 185665       9/30/20 13:45   Testing_Alarm - Confirmed with DBM, Testing b...
# 185666       9/30/20 13:46   True_Normal - Alarm - Confirmed with Security...
# 185667       9/30/20 13:46   Testing_Alarm - Confirmed with BM, Testing by...
# 185668       9/30/20 13:51  True_Normal - Alarm - Confirmed with DBM, Acci...
# 185669       9/30/20 13:51  True_Normal - Alarm - Confirmed with DBM, Acci...
# 185670       9/30/20 13:51  True_Normal - Alarm - Confirmed with DBM, Acci...
# 185671       9/30/20 13:52   True_Normal - Confirmed with BM, Delay in Dis...
# 185672       9/30/20 13:53   True_Normal - Confirmed with BM, Delay in Dis...
# 185673       9/30/20 13:54   Testing_Alarm - Confirmed with BM, Testing by...
# 185674       9/30/20 13:54   Testing_Alarm - Confirmed with BM, Testing by...
# 185675       9/30/20 13:59  True_Normal - Alarm - Confirmed with DBM, Acci...
# 185676       9/30/20 14:00  True_Normal - Alarm - Confirmed with DBM, Acci...
# 185677       9/30/20 14:00  True_Normal - Alarm - Confirmed with DBM, Acci...
# 185678       9/30/20 14:04  True_Normal - Alarm - Confirmed with DBM, Acci...
# 185679       9/30/20 14:04  True_Normal - Alarm - Confirmed with DBM, Acci...
# 185680       9/30/20 14:10  True_Normal - Alarm - Confirmed with DBM, Acci...
# 185681       9/30/20 14:10  True_Normal - Alarm - Confirmed with DBM, Acci...
# 185682       9/30/20 14:10  True_Normal - Alarm - Confirmed with DBM, Acci...
# 185683       9/30/20 14:10  True_Normal - Alarm - Confirmed with DBM, Acci...
# 185684       9/30/20 14:11   Testing_Alarm - Confirmed with DBM, Testing b...
# 185685       9/30/20 14:11   Testing_Alarm - Confirmed with DBM, Testing b...
# 185686       9/30/20 14:11   Testing_Alarm - Confirmed with DBM, Testing b...
#
#                      Confirmation    LOG ID  \
# 0           Confirmed via Portal   46795597
# 1              Confirmed via TWAC  46786573
# 2           Confirmed via Portal   46796697
# 3           Confirmed via Portal   46797661
# 4           Confirmed via Portal   46800167
# 5              Confirmed via CCTV  46790665
# 6           Confirmed via Portal   46800169
# 7           Confirmed via Portal   46801387
# 8              Confirmed via TWAC  46792871
# 9              Confirmed via TWAC  46792911
# 10             Confirmed via TWAC  46794081
# 11          Confirmed via Portal   46805815
# 12        Confirmed with Security  46797067
# 13             Confirmed via CCTV  46799859
# 14        Confirmed with Security  46800847
# 15             Confirmed via CCTV  46802319
# 16          Confirmed via Portal   46812037
# 17             Confirmed via TWAC  46803307
# 18          Confirmed via Portal   46814495
# 19             Confirmed via CCTV  46806509
# 20             Confirmed via CCTV  46807121
# 21          Confirmed via Portal   46814969
# 22             Confirmed via CCTV  46810215
# 23          Confirmed via Portal   46816329
# 24             Confirmed via CCTV  46812007
# 25             Confirmed via CCTV  46812047
# 26             Confirmed via CCTV  46814689
# 27          Confirmed via Portal   46819479
# 28             Confirmed with DBM  46816215
# 29        Confirmed with Security  46817007
# ...                           ...       ...
# 185657          Confirmed with BM  66120369
# 185658          Confirmed with BM  66120377
# 185659          Confirmed with BM  66120399
# 185660          Confirmed with BM  66120397
# 185661          Confirmed with BM  66120479
# 185662          Confirmed with BM  66120489
# 185663         Confirmed with DBM  66120531
# 185664         Confirmed with DBM  66120545
# 185665         Confirmed with DBM  66120577
# 185666   Confirmed with Security   66120601
# 185667          Confirmed with BM  66120605
# 185668         Confirmed with DBM  66120917
# 185669         Confirmed with DBM  66120933
# 185670         Confirmed with DBM  66120939
# 185671          Confirmed with BM  66121003
# 185672          Confirmed with BM  66121039
# 185673          Confirmed with BM  66121127
# 185674          Confirmed with BM  66121131
# 185675         Confirmed with DBM  66121359
# 185676         Confirmed with DBM  66121389
# 185677         Confirmed with DBM  66121399
# 185678         Confirmed with DBM  66121701
# 185679         Confirmed with DBM  66121703
# 185680         Confirmed with DBM  66121951
# 185681         Confirmed with DBM  66121957
# 185682         Confirmed with DBM  66121955
# 185683         Confirmed with DBM  66121971
# 185684         Confirmed with DBM  66121991
# 185685         Confirmed with DBM  66122009
# 185686         Confirmed with DBM  66122023
#
#                                     2nd AKNOWLEDGE STATUS         Status  \
# 0       True Alarm - Confirmed via Portal & Escalated ...  True_Critical
# 1       \nFalse_False_Alarm - Branch Closed,  Verified...    False_False
# 2       True Alarm - Confirmed via Portal & Escalated ...  True_Critical
# 3       True Alarm - Confirmed via Portal & Escalated ...  True_Critical
# 4       True Alarm - Confirmed via Portal & Escalated ...  True_Critical
# 5                   False_False_Alarm - Verified via CCTV    False_False
# 6       True Alarm - Confirmed via Portal & Escalated ...  True_Critical
# 7       True Alarm - Confirmed via Portal & Escalated ...  True_Critical
# 8       False_False_Alarm - Branch Closed, Confirmed v...    False_False
# 9       False_False_Alarm - Branch Closed, Confirmed v...    False_False
# 10      False_False_Alarm - Branch Closed, Confirmed v...    False_False
# 11       True Alarm - Confirmed via Portal & Escalated...  True_Critical
# 12           False_False_Alarm - Confirmed with security.    False_False
# 13      False_False_Alarm - Branch Closed,  Verified C...    False_False
# 14          False_False_Alarm - Confirmed with security.     False_False
# 15                    False_False_Alarm - Verified CCTV.     False_False
# 16       True Alarm - Confirmed via Portal & Escalated...  True_Critical
# 17      False_False_Alarm - Branch Closed, . VerifiedT...    False_False
# 18       True Alarm - Confirmed via Portal & Escalated...  True_Critical
# 19      False_False_Alarm - Branch Closed, Confirmed v...    False_False
# 20                    False_False_Alarm - Verified CCTV.     False_False
# 21       True Alarm - Confirmed via Portal & Escalated...  True_Critical
# 22      False_False_Alarm - Branch Closed, Confirmed v...    False_False
# 23       True Alarm - Confirmed via Portal & Escalated...  True_Critical
# 24      False_False_Alarm - Branch Closed, Confirmed v...    False_False
# 25      False_False_Alarm - Branch Closed, Confirmed v...    False_False
# 26      False_False_Alarm - Branch Closed, Verified CC...    False_False
# 27       True Alarm - Confirmed via Portal & Escalated...  True_Critical
# 28      False_False_Alarm - Branch Closed, Confirmed w...    False_False
# 29      False_False_Alarm - Branch Closed, Confirmed w...    False_False
# ...                                                   ...            ...
# 185657   Testing_Alarm - Confirmed with BM, Testing by...        Testing
# 185658   Testing_Alarm - Confirmed with BM, Testing by...        Testing
# 185659   Testing_Alarm - Confirmed with BM, Testing by...        Testing
# 185660   Testing_Alarm - Confirmed with BM, Testing by...        Testing
# 185661   Testing_Alarm - Confirmed with BM, Testing by...        Testing
# 185662   Testing_Alarm - Confirmed with BM, Testing by...        Testing
# 185663   Testing_Alarm - Confirmed with DBM, Testing b...        Testing
# 185664   Testing_Alarm - Confirmed with DBM, Testing b...        Testing
# 185665   Testing_Alarm - Confirmed with DBM, Testing b...        Testing
# 185666   True_Normal - Alarm - Confirmed with Security...    True_Normal
# 185667   Testing_Alarm - Confirmed with BM, Testing by...        Testing
# 185668  True_Normal - Alarm - Confirmed with DBM, Acci...    True_Normal
# 185669  True_Normal - Alarm - Confirmed with DBM, Acci...    True_Normal
# 185670  True_Normal - Alarm - Confirmed with DBM, Acci...    True_Normal
# 185671   True_Normal - Confirmed with BM, Delay in Dis...    True_Normal
# 185672   True_Normal - Confirmed with BM, Delay in Dis...    True_Normal
# 185673   Testing_Alarm - Confirmed with BM, Testing by...        Testing
# 185674   Testing_Alarm - Confirmed with BM, Testing by...        Testing
# 185675  True_Normal - Alarm - Confirmed with DBM, Acci...    True_Normal
# 185676  True_Normal - Alarm - Confirmed with DBM, Acci...    True_Normal
# 185677  True_Normal - Alarm - Confirmed with DBM, Acci...    True_Normal
# 185678  True_Normal - Alarm - Confirmed with DBM, Acci...    True_Normal
# 185679  True_Normal - Alarm - Confirmed with DBM, Acci...    True_Normal
# 185680  True_Normal - Alarm - Confirmed with DBM, Acci...    True_Normal
# 185681  True_Normal - Alarm - Confirmed with DBM, Acci...    True_Normal
# 185682  True_Normal - Alarm - Confirmed with DBM, Acci...    True_Normal
# 185683  True_Normal - Alarm - Confirmed with DBM, Acci...    True_Normal
# 185684   Testing_Alarm - Confirmed with DBM, Testing b...        Testing
# 185685   Testing_Alarm - Confirmed with DBM, Testing b...        Testing
# 185686   Testing_Alarm - Confirmed with DBM, Testing b...        Testing
#
#             Month                            Reason
# 0             Apr       Network communication error
# 1             Apr  Verified / Confirmed False alert
# 2             Apr       Network communication error
# 3             Apr       Network communication error
# 4             Apr       Network communication error
# 5             Apr  Verified / Confirmed False alert
# 6             Apr       Network communication error
# 7             Apr       Network communication error
# 8             Apr  Verified / Confirmed False alert
# 9             Apr  Verified / Confirmed False alert
# 10            Apr  Verified / Confirmed False alert
# 11            Apr       Network communication error
# 12            Apr  Verified / Confirmed False alert
# 13            Apr  Verified / Confirmed False alert
# 14            Apr  Verified / Confirmed False alert
# 15            Apr  Verified / Confirmed False alert
# 16            Apr       Network communication error
# 17            Apr  Verified / Confirmed False alert
# 18            Apr       Network communication error
# 19            Apr  Verified / Confirmed False alert
# 20            Apr  Verified / Confirmed False alert
# 21            Apr       Network communication error
# 22            Apr  Verified / Confirmed False alert
# 23            Apr       Network communication error
# 24            Apr  Verified / Confirmed False alert
# 25            Apr  Verified / Confirmed False alert
# 26            Apr  Verified / Confirmed False alert
# 27            Apr       Network communication error
# 28            Apr  Verified / Confirmed False alert
# 29            Apr  Verified / Confirmed False alert
# ...           ...                               ...
# 185657  September                    Testing by FSE
# 185658  September                    Testing by FSE
# 185659  September                    Testing by FSE
# 185660  September                    Testing by FSE
# 185661  September                    Testing by FSE
# 185662  September                    Testing by FSE
# 185663  September                    Testing by FSE
# 185664  September                    Testing by FSE
# 185665  September                    Testing by FSE
# 185666  September  Accidentally done by bank staff.
# 185667  September                    Testing by FSE
# 185668  September  Accidentally done by bank staff.
# 185669  September  Accidentally done by bank staff.
# 185670  September  Accidentally done by bank staff.
# 185671  September                   Delay in Disarm
# 185672  September                   Delay in Disarm
# 185673  September                    Testing by FSE
# 185674  September                    Testing by FSE
# 185675  September  Accidentally done by bank staff.
# 185676  September  Accidentally done by bank staff.
# 185677  September  Accidentally done by bank staff.
# 185678  September  Accidentally done by bank staff.
# 185679  September  Accidentally done by bank staff.
# 185680  September  Accidentally done by bank staff.
# 185681  September  Accidentally done by bank staff.
# 185682  September  Accidentally done by bank staff.
# 185683  September  Accidentally done by bank staff.
# 185684  September                    Testing by FSE
# 185685  September                    Testing by FSE
# 185686  September                    Testing by FSE
#
# [185687 rows x 16 columns]

# %% [markdown]
# ## Showing first 5 rows of the dataset

# %%
data.head(5)
# Out:
#        DATE SOL ID                          Branch     SENSOR (As of Portal)  \
# 0  1-Apr-20   6358       MH_6358_Vasant Rutu Plaza                    System
# 1  1-Apr-20   6116          TN_6116_Ramanathapuram  PIR - Inside Strong Room
# 2  1-Apr-20   4407         AP_4407_Pandurangapuram                    System
# 3  1-Apr-20   6973        MH_OPX_6973_Ichalkaranji                    System
# 4  1-Apr-20   0066  PJ_0066_Amritsar_Lawrence Road                    System
#
#   Region           STATE SENSOR NAME (Standard)  \
# 0   West     Maharashtra                Network
# 1  South              TN                    PIR
# 2  South  Andhra Pradesh                Network
# 3   West     Maharashtra                Network
# 4  North          Punjab                Network
#
#                              EVENT EVENT DATE AND TIME  \
# 0      Network communication error         4/1/20 0:07
# 1  PIR Motion Detected Armed Hours         4/1/20 0:11
# 2      Network communication error         4/1/20 0:15
# 3      Network communication error         4/1/20 0:27
# 4      Network communication error         4/1/20 0:46
#
#                                    AKNOWLEDGE STATUS           Confirmation  \
# 0  True Alarm - Confirmed via Portal & Escalated ...  Confirmed via Portal
# 1  \nFalse_False_Alarm - Branch Closed,  Verified...     Confirmed via TWAC
# 2  True Alarm - Confirmed via Portal & Escalated ...  Confirmed via Portal
# 3  True Alarm - Confirmed via Portal & Escalated ...  Confirmed via Portal
# 4  True Alarm - Confirmed via Portal & Escalated ...  Confirmed via Portal
#
#      LOG ID                              2nd AKNOWLEDGE STATUS         Status  \
# 0  46795597  True Alarm - Confirmed via Portal & Escalated ...  True_Critical
# 1  46786573  \nFalse_False_Alarm - Branch Closed,  Verified...    False_False
# 2  46796697  True Alarm - Confirmed via Portal & Escalated ...  True_Critical
# 3  46797661  True Alarm - Confirmed via Portal & Escalated ...  True_Critical
# 4  46800167  True Alarm - Confirmed via Portal & Escalated ...  True_Critical
#
#   Month                            Reason
# 0   Apr       Network communication error
# 1   Apr  Verified / Confirmed False alert
# 2   Apr       Network communication error
# 3   Apr       Network communication error
# 4   Apr       Network communication error

# %% [markdown]
# # Shape

# %%
data.shape
# Out:
# (185687, 16)

# %% [markdown]
# ## Counting the output values for each categories

# %%
data.Status.value_counts().count
# Out:
# <bound method Series.count of True_Normal      110395
#  Testing          36442
#  False_False      23755
# True_Critical     10505
# FALSE              4590
# Name: Status, dtype: int64>

# %% [markdown]
# # Features of the data set

# %%
data.columns
# Out:
# Index(['DATE', 'SOL ID', 'Branch', 'SENSOR (As of Portal)', 'Region', 'STATE',
#        'SENSOR NAME (Standard)', ' EVENT', 'EVENT DATE AND TIME',
#        'AKNOWLEDGE STATUS', 'Confirmation', 'LOG ID', '2nd AKNOWLEDGE STATUS',
#        'Status', 'Month', 'Reason'],
#       dtype='object')

# %% [markdown]
# ## Number of distinct observations

# %%
data.nunique()
# Out:
# DATE                         177
# SOL ID                      1721
# Branch                      1793
# SENSOR (As of Portal)       1327
# Region                         4
# STATE                         22
# SENSOR NAME (Standard)        19
#  EVENT                        14
# EVENT DATE AND TIME        73423
# AKNOWLEDGE STATUS           9864
# Confirmation                  36
# LOG ID                    185475
# 2nd AKNOWLEDGE STATUS      10078
# Status                         5
# Month                          6
# Reason                        18
# dtype: int64

# %% [markdown]
# # Removing the unnecessary features

# %%
p=data.drop(['LOG ID','SENSOR (As of Portal)','DATE','SENSOR NAME (Standard)', 'Month','EVENT DATE AND TIME','Reason'], axis=1)
p
# Out:
#        SOL ID                               Branch Region           STATE  \
# 0        6358            MH_6358_Vasant Rutu Plaza   West     Maharashtra
# 1        6116               TN_6116_Ramanathapuram  South              TN
# 2        4407              AP_4407_Pandurangapuram  South  Andhra Pradesh
# 3        6973             MH_OPX_6973_Ichalkaranji   West     Maharashtra
# 4        0066       PJ_0066_Amritsar_Lawrence Road  North          Punjab
# 5        1453                 MH_OPX_1453_Malkapur   West     Maharashtra
# 6        2314          UP_OPX_2314_Transport_Nagar  North              UP
# 7        4057                       MH_4057_Mehkar   West     Maharashtra
# 8        0233                  HR_0233_Ambala_City  North         Haryana
# 9        0233                  HR_0233_Ambala_City  North         Haryana
# 10       ICMC           AP_ICMC_Vizag_Ground_Floor  South  Andhra Pradesh
# 11       1107                   MH_OPX_1107_Udhgir   West     Maharashtra
# 12       0181                       KL_0181_Kannur  South          Kerala
# 13       6065                   TN_OPX_6065_Kallal  South              TN
# 14       0181                       KL_0181_Kannur  South          Kerala
# 15       0633                    JH_OPX_0633_Gumla  North       Jharkhand
# 16       7396          MH_7396_Katraj_Kondhwa_Road   West     Maharashtra
# 17       0273       PJ_0273_Jalandhar_Adarsh Nagar  North          Punjab
# 18       4062                      MP_4062_Rajgarh   West              MP
# 19       2556  BR_OPX_2556_Barauni_Mirchaiya_Chauk  North           Bihar
# 20       0633                    JH_OPX_0633_Gumla  North       Jharkhand
# 21       3951                   AP_3951_Markapuram  South  Andhra Pradesh
# 22       2556  BR_OPX_2556_Barauni_Mirchaiya_Chauk  North           Bihar
# 23       0162       PJ_0162_Patiala_chottibaradari  North          Punjab
# 24       1979                     AP_OPX_1979_Tuni  South  Andhra Pradesh
# 25       1979                     AP_OPX_1979_Tuni  South  Andhra Pradesh
# 26       6065                   TN_OPX_6065_Kallal  South              TN
# 27       7522                       GJ_7522_Bherai   West         Gujarat
# 28       6394                  MH_OPX_6394_Tasgaon   West     Maharashtra
# 29       1740                    GJ_1740_Changodar   West         Gujarat
# ...       ...                                  ...    ...             ...
# 185657   2177             AH_RJ_OPX_2177_Army Area   West       Rajasthan
# 185658   2177             AH_RJ_OPX_2177_Army Area   West       Rajasthan
# 185659   2177             AH_RJ_OPX_2177_Army Area   West       Rajasthan
# 185660   2177             AH_RJ_OPX_2177_Army Area   West       Rajasthan
# 185661   2177             AH_RJ_OPX_2177_Army Area   West       Rajasthan
# 185662   2177             AH_RJ_OPX_2177_Army Area   West       Rajasthan
# 185663   2797                OR_OPX_2797_Baramunda   East          Orissa
# 185664   2797                OR_OPX_2797_Baramunda   East          Orissa
# 185665   2797                OR_OPX_2797_Baramunda   East          Orissa
# 185666   1400          HR_1400_Faridabad_Sector_19  North         Haryana
# 185667   2177             AH_RJ_OPX_2177_Army Area   West       Rajasthan
# 185668   3045                 OR_OPX_3045_Karanjia   East          Orissa
# 185669   3045                 OR_OPX_3045_Karanjia   East          Orissa
# 185670   3045                 OR_OPX_3045_Karanjia   East          Orissa
# 185671   7207                     RJ_7207_Sitabari   West       Rajasthan
# 185672   7207                     RJ_7207_Sitabari   West       Rajasthan
# 185673   2177             AH_RJ_OPX_2177_Army Area   West       Rajasthan
# 185674   2177             AH_RJ_OPX_2177_Army Area   West       Rajasthan
# 185675   6656              RJ_OPX_6656_Bachh_Khera   West       Rajasthan
# 185676   6656              RJ_OPX_6656_Bachh_Khera   West       Rajasthan
# 185677   6656              RJ_OPX_6656_Bachh_Khera   West       Rajasthan
# 185678   7247                       GJ_7247_Saroli   West         Gujarat
# 185679   7247                       GJ_7247_Saroli   West         Gujarat
# 185680   6707              RJ_6707_Sri Ganga Nagar   West       Rajasthan
# 185681   6707              RJ_6707_Sri Ganga Nagar   West       Rajasthan
# 185682   6707              RJ_6707_Sri Ganga Nagar   West       Rajasthan
# 185683   6707              RJ_6707_Sri Ganga Nagar   West       Rajasthan
# 185684   2797                OR_OPX_2797_Baramunda   East          Orissa
# 185685   2797                OR_OPX_2797_Baramunda   East          Orissa
# 185686   2797                OR_OPX_2797_Baramunda   East          Orissa
#
#                                   EVENT  \
# 0           Network communication error
# 1       PIR Motion Detected Armed Hours
# 2           Network communication error
# 3           Network communication error
# 4           Network communication error
# 5                    Vibration Detected
# 6           Network communication error
# 7           Network communication error
# 8       PIR Motion Detected Armed Hours
# 9                             Hooter ON
# 10              Open during Armed Hours
# 11          Network communication error
# 12                   Vibration Detected
# 13              Open during Armed Hours
# 14                   Vibration Detected
# 15                   Vibration Detected
# 16          Network communication error
# 17      PIR Motion Detected Armed Hours
# 18          Network communication error
# 19      PIR Motion Detected Armed Hours
# 20                   Vibration Detected
# 21          Network communication error
# 22      PIR Motion Detected Armed Hours
# 23          Network communication error
# 24      PIR Motion Detected Armed Hours
# 25                            Hooter ON
# 26              Open during Armed Hours
# 27          Network communication error
# 28                            Hooter ON
# 29      PIR Motion Detected Armed Hours
# ...                                 ...
# 185657                      Smoke Alarm
# 185658                        Hooter ON
# 185659                 Stop Panic Alarm
# 185660                        Hooter ON
# 185661                        Hooter ON
# 185662                 Stop Panic Alarm
# 185663                      Smoke Alarm
# 185664                        Hooter ON
# 185665                 Stop Panic Alarm
# 185666                 Stop Panic Alarm
# 185667                        Hooter ON
# 185668                      Panic Alarm
# 185669                        Hooter ON
# 185670                 Stop Panic Alarm
# 185671                        Hooter ON
# 185672                 Stop Panic Alarm
# 185673                      Panic Alarm
# 185674                 Stop Panic Alarm
# 185675                      Panic Alarm
# 185676                        Hooter ON
# 185677                 Stop Panic Alarm
# 185678                        Hooter ON
# 185679                 Stop Panic Alarm
# 185680                        Hooter ON
# 185681                      Panic Alarm
# 185682                        Hooter ON
# 185683                 Stop Panic Alarm
# 185684                      Smoke Alarm
# 185685                        Hooter ON
# 185686                 Stop Panic Alarm
#
#                                         AKNOWLEDGE STATUS  \
# 0       True Alarm - Confirmed via Portal & Escalated ...
# 1       \nFalse_False_Alarm - Branch Closed,  Verified...
# 2       True Alarm - Confirmed via Portal & Escalated ...
# 3       True Alarm - Confirmed via Portal & Escalated ...
# 4       True Alarm - Confirmed via Portal & Escalated ...
# 5                   False_False_Alarm - Verified via CCTV
# 6       True Alarm - Confirmed via Portal & Escalated ...
# 7       True Alarm - Confirmed via Portal & Escalated ...
# 8       False_False_Alarm - Branch Closed, Confirmed v...
# 9       False_False_Alarm - Branch Closed, Confirmed v...
# 10      False_False_Alarm - Branch Closed, Confirmed v...
# 11       True Alarm - Confirmed via Portal & Escalated...
# 12           False_False_Alarm - Confirmed with security.
# 13      False_False_Alarm - Branch Closed,  Verified C...
# 14          False_False_Alarm - Confirmed with security.
# 15                    False_False_Alarm - Verified CCTV.
# 16       True Alarm - Confirmed via Portal & Escalated...
# 17      False_False_Alarm - Branch Closed, . VerifiedT...
# 18       True Alarm - Confirmed via Portal & Escalated...
# 19      False_False_Alarm - Branch Closed, Confirmed v...
# 20                    False_False_Alarm - Verified CCTV.
# 21       True Alarm - Confirmed via Portal & Escalated...
# 22      False_False_Alarm - Branch Closed, Confirmed v...
# 23       True Alarm - Confirmed via Portal & Escalated...
# 24      False_False_Alarm - Branch Closed, Confirmed v...
# 25      False_False_Alarm - Branch Closed, Confirmed v...
# 26      False_False_Alarm - Branch Closed, Verified CC...
# 27       True Alarm - Confirmed via Portal & Escalated...
# 28      False_False_Alarm - Branch Closed, Confirmed w...
# 29      False_False_Alarm - Branch Closed, Confirmed w...
# ...                                                   ...
# 185657   Testing_Alarm - Confirmed with BM, Testing by...
# 185658   Testing_Alarm - Confirmed with BM, Testing by...
# 185659   Testing_Alarm - Confirmed with BM, Testing by...
# 185660   Testing_Alarm - Confirmed with BM, Testing by...
# 185661   Testing_Alarm - Confirmed with BM, Testing by...
# 185662   Testing_Alarm - Confirmed with BM, Testing by...
# 185663   Testing_Alarm - Confirmed with DBM, Testing b...
# 185664   Testing_Alarm - Confirmed with DBM, Testing b...
# 185665   Testing_Alarm - Confirmed with DBM, Testing b...
# 185666   True_Normal - Alarm - Confirmed with Security...
# 185667   Testing_Alarm - Confirmed with BM, Testing by...
# 185668  True_Normal - Alarm - Confirmed with DBM, Acci...
# 185669  True_Normal - Alarm - Confirmed with DBM, Acci...
# 185670  True_Normal - Alarm - Confirmed with DBM, Acci...
# 185671   True_Normal - Confirmed with BM, Delay in Dis...
# 185672   True_Normal - Confirmed with BM, Delay in Dis...
# 185673   Testing_Alarm - Confirmed with BM, Testing by...
# 185674   Testing_Alarm - Confirmed with BM, Testing by...
# 185675  True_Normal - Alarm - Confirmed with DBM, Acci...
# 185676  True_Normal - Alarm - Confirmed with DBM, Acci...
# 185677  True_Normal - Alarm - Confirmed with DBM, Acci...
# 185678  True_Normal - Alarm - Confirmed with DBM, Acci...
# 185679  True_Normal - Alarm - Confirmed with DBM, Acci...
# 185680  True_Normal - Alarm - Confirmed with DBM, Acci...
# 185681  True_Normal - Alarm - Confirmed with DBM, Acci...
# 185682  True_Normal - Alarm - Confirmed with DBM, Acci...
# 185683  True_Normal - Alarm - Confirmed with DBM, Acci...
# 185684   Testing_Alarm - Confirmed with DBM, Testing b...
# 185685   Testing_Alarm - Confirmed with DBM, Testing b...
# 185686   Testing_Alarm - Confirmed with DBM, Testing b...
#
#                      Confirmation  \
# 0           Confirmed via Portal
# 1              Confirmed via TWAC
# 2           Confirmed via Portal
# 3           Confirmed via Portal
# 4           Confirmed via Portal
# 5              Confirmed via CCTV
# 6           Confirmed via Portal
# 7           Confirmed via Portal
# 8              Confirmed via TWAC
# 9              Confirmed via TWAC
# 10             Confirmed via TWAC
# 11          Confirmed via Portal
# 12        Confirmed with Security
# 13             Confirmed via CCTV
# 14        Confirmed with Security
# 15             Confirmed via CCTV
# 16          Confirmed via Portal
# 17             Confirmed via TWAC
# 18          Confirmed via Portal
# 19             Confirmed via CCTV
# 20             Confirmed via CCTV
# 21          Confirmed via Portal
# 22             Confirmed via CCTV
# 23          Confirmed via Portal
# 24             Confirmed via CCTV
# 25             Confirmed via CCTV
# 26             Confirmed via CCTV
# 27          Confirmed via Portal
# 28             Confirmed with DBM
# 29        Confirmed with Security
# ...                           ...
# 185657          Confirmed with BM
# 185658          Confirmed with BM
# 185659          Confirmed with BM
# 185660          Confirmed with BM
# 185661          Confirmed with BM
# 185662          Confirmed with BM
# 185663         Confirmed with DBM
# 185664         Confirmed with DBM
# 185665         Confirmed with DBM
# 185666   Confirmed with Security
# 185667          Confirmed with BM
# 185668         Confirmed with DBM
# 185669         Confirmed with DBM
# 185670         Confirmed with DBM
# 185671          Confirmed with BM
# 185672          Confirmed with BM
# 185673          Confirmed with BM
# 185674          Confirmed with BM
# 185675         Confirmed with DBM
# 185676         Confirmed with DBM
# 185677         Confirmed with DBM
# 185678         Confirmed with DBM
# 185679         Confirmed with DBM
# 185680         Confirmed with DBM
# 185681         Confirmed with DBM
# 185682         Confirmed with DBM
# 185683         Confirmed with DBM
# 185684         Confirmed with DBM
# 185685         Confirmed with DBM
# 185686         Confirmed with DBM
#
#                                     2nd AKNOWLEDGE STATUS         Status
# 0       True Alarm - Confirmed via Portal & Escalated ...  True_Critical
# 1       \nFalse_False_Alarm - Branch Closed,  Verified...    False_False
# 2       True Alarm - Confirmed via Portal & Escalated ...  True_Critical
# 3       True Alarm - Confirmed via Portal & Escalated ...  True_Critical
# 4       True Alarm - Confirmed via Portal & Escalated ...  True_Critical
# 5                   False_False_Alarm - Verified via CCTV    False_False
# 6       True Alarm - Confirmed via Portal & Escalated ...  True_Critical
# 7       True Alarm - Confirmed via Portal & Escalated ...  True_Critical
# 8       False_False_Alarm - Branch Closed, Confirmed v...    False_False
# 9       False_False_Alarm - Branch Closed, Confirmed v...    False_False
# 10      False_False_Alarm - Branch Closed, Confirmed v...    False_False
# 11       True Alarm - Confirmed via Portal & Escalated...  True_Critical
# 12           False_False_Alarm - Confirmed with security.    False_False
# 13      False_False_Alarm - Branch Closed,  Verified C...    False_False
# 14          False_False_Alarm - Confirmed with security.     False_False
# 15                    False_False_Alarm - Verified CCTV.     False_False
# 16       True Alarm - Confirmed via Portal & Escalated...  True_Critical
# 17      False_False_Alarm - Branch Closed, . VerifiedT...    False_False
# 18       True Alarm - Confirmed via Portal & Escalated...  True_Critical
# 19      False_False_Alarm - Branch Closed, Confirmed v...    False_False
# 20                    False_False_Alarm - Verified CCTV.     False_False
# 21       True Alarm - Confirmed via Portal & Escalated...  True_Critical
# 22      False_False_Alarm - Branch Closed, Confirmed v...    False_False
# 23       True Alarm - Confirmed via Portal & Escalated...  True_Critical
# 24      False_False_Alarm - Branch Closed, Confirmed v...    False_False
# 25      False_False_Alarm - Branch Closed, Confirmed v...    False_False
# 26      False_False_Alarm - Branch Closed, Verified CC...    False_False
# 27       True Alarm - Confirmed via Portal & Escalated...  True_Critical
# 28      False_False_Alarm - Branch Closed, Confirmed w...    False_False
# 29      False_False_Alarm - Branch Closed, Confirmed w...    False_False
# ...                                                   ...            ...
# 185657   Testing_Alarm - Confirmed with BM, Testing by...        Testing
# 185658   Testing_Alarm - Confirmed with BM, Testing by...        Testing
# 185659   Testing_Alarm - Confirmed with BM, Testing by...        Testing
# 185660   Testing_Alarm - Confirmed with BM, Testing by...        Testing
# 185661   Testing_Alarm - Confirmed with BM, Testing by...        Testing
# 185662   Testing_Alarm - Confirmed with BM, Testing by...        Testing
# 185663   Testing_Alarm - Confirmed with DBM, Testing b...        Testing
# 185664   Testing_Alarm - Confirmed with DBM, Testing b...        Testing
# 185665   Testing_Alarm - Confirmed with DBM, Testing b...        Testing
# 185666   True_Normal - Alarm - Confirmed with Security...    True_Normal
# 185667   Testing_Alarm - Confirmed with BM, Testing by...        Testing
# 185668  True_Normal - Alarm - Confirmed with DBM, Acci...    True_Normal
# 185669  True_Normal - Alarm - Confirmed with DBM, Acci...    True_Normal
# 185670  True_Normal - Alarm - Confirmed with DBM, Acci...    True_Normal
# 185671   True_Normal - Confirmed with BM, Delay in Dis...    True_Normal
# 185672   True_Normal - Confirmed with BM, Delay in Dis...    True_Normal
# 185673   Testing_Alarm - Confirmed with BM, Testing by...        Testing
# 185674   Testing_Alarm - Confirmed with BM, Testing by...        Testing
# 185675  True_Normal - Alarm - Confirmed with DBM, Acci...    True_Normal
# 185676  True_Normal - Alarm - Confirmed with DBM, Acci...    True_Normal
# 185677  True_Normal - Alarm - Confirmed with DBM, Acci...    True_Normal
# 185678  True_Normal - Alarm - Confirmed with DBM, Acci...    True_Normal
# 185679  True_Normal - Alarm - Confirmed with DBM, Acci...    True_Normal
# 185680  True_Normal - Alarm - Confirmed with DBM, Acci...    True_Normal
# 185681  True_Normal - Alarm - Confirmed with DBM, Acci...    True_Normal
# 185682  True_Normal - Alarm - Confirmed with DBM, Acci...    True_Normal
# 185683  True_Normal - Alarm - Confirmed with DBM, Acci...    True_Normal
# 185684   Testing_Alarm - Confirmed with DBM, Testing b...        Testing
# 185685   Testing_Alarm - Confirmed with DBM, Testing b...        Testing
# 185686   Testing_Alarm - Confirmed with DBM, Testing b...        Testing
#
# [185687 rows x 9 columns]

# %% [markdown]
# ## Checking for NaN/null values

# %%
p.isna().sum()
# Out:
# SOL ID                   0
# Branch                   0
# Region                   0
# STATE                    0
#  EVENT                   0
# AKNOWLEDGE STATUS        0
# Confirmation             0
# 2nd AKNOWLEDGE STATUS    0
# Status                   0
# dtype: int64

# %% [markdown]
# ## Handling categorical data

# %% [markdown]
# Here we are converting categorical data to numerical data using label encoder

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder_X=LabelEncoder()
xm=p.apply(LabelEncoder().fit_transform)
xm
# Out:
#         SOL ID  Branch  Region  STATE   EVENT  AKNOWLEDGE STATUS  \
# 0         1255     619       3     11       6               7872
# 1         1166    1383       2     17       8                434
# 2         1092      62       2      0       6               7872
# 3         1525     781       3     11       6               7872
# 4           11     893       1     15       6               7872
# 5          450     675       3     11      13               1994
# 6          713    1746       1     19       6               7872
# 7          943     607       3     11       6               7872
# 8           48     334       1      5       8               5356
# 9           48     334       1      5       5               5356
# 10        1711      80       2      0       7               5356
# 11         356     668       3     11       6               3237
# 12          26     442       2      9      13               5671
# 13        1127    1515       2     17       7               5326
# 14          26     442       2      9      13               1956
# 15         163     372       1      7      13               1980
# 16        1609     641       3     11       6               3237
# 17          62     901       1     15       8               5338
# 18         947     825       3     10       6               3237
# 19         770     129       1      1       8               5360
# 20         163     372       1      7      13               1980
# 21         891      41       2      0       6               3237
# 22         770     129       1      1       8               5360
# 23          18     895       1     15       6               3237
# 24         660     102       2      0       8               5360
# 25         660     102       2      0       5               5360
# 26        1127    1515       2     17       7               5449
# 27        1664     296       3      4       6               3237
# 28        1280     757       3     11       5               5387
# 29         566     222       3      4       8               5400
# ...        ...     ...     ...    ...     ...                ...
# 185657     705      16       3     16      10               2682
# 185658     705      16       3     16       5               2682
# 185659     705      16       3     16      12               2682
# 185660     705      16       3     16       5               2682
# 185661     705      16       3     16       5               2682
# 185662     705      16       3     16      12               2682
# 185663     807     882       0     13      10               2968
# 185664     807     882       0     13       5               2968
# 185665     807     882       0     13      12               2968
# 185666     436     341       1      5      12               3415
# 185667     705      16       3     16       5               2682
# 185668     833     884       0     13       9               8337
# 185669     833     884       0     13       5               8337
# 185670     833     884       0     13      12               8337
# 185671    1536    1074       3     16       5               3466
# 185672    1536    1074       3     16      12               3466
# 185673     705      16       3     16       9               2682
# 185674     705      16       3     16      12               2682
# 185675    1341    1107       3     16       9               8337
# 185676    1341    1107       3     16       5               8337
# 185677    1341    1107       3     16      12               8337
# 185678    1552     282       3      4       5               8337
# 185679    1552     282       3      4      12               8337
# 185680    1369    1022       3     16       5               8337
# 185681    1369    1022       3     16       9               8337
# 185682    1369    1022       3     16       5               8337
# 185683    1369    1022       3     16      12               8337
# 185684     807     882       0     13      10               2968
# 185685     807     882       0     13       5               2968
# 185686     807     882       0     13      12               2968
#
#         Confirmation  2nd AKNOWLEDGE STATUS  Status
# 0                 14                   8079       3
# 1                 15                    442       0
# 2                 14                   8079       3
# 3                 14                   8079       3
# 4                 14                   8079       3
# 5                 12                   2070       0
# 6                 14                   8079       3
# 7                 14                   8079       3
# 8                 15                   5517       0
# 9                 15                   5517       0
# 10                15                   5517       0
# 11                14                   3313       3
# 12                26                   5864       0
# 13                12                   5487       0
# 14                26                   2031       0
# 15                12                   2055       0
# 16                14                   3313       3
# 17                15                   5499       0
# 18                14                   3313       3
# 19                12                   5522       0
# 20                12                   2055       0
# 21                14                   3313       3
# 22                12                   5522       0
# 23                14                   3313       3
# 24                12                   5522       0
# 25                12                   5522       0
# 26                12                   5616       0
# 27                14                   3313       3
# 28                19                   5552       0
# 29                26                   5565       0
# ...              ...                    ...     ...
# 185657             1                   2748       1
# 185658             1                   2748       1
# 185659             1                   2748       1
# 185660             1                   2748       1
# 185661             1                   2748       1
# 185662             1                   2748       1
# 185663            19                   3045       1
# 185664            19                   3045       1
# 185665            19                   3045       1
# 185666             8                   3488       4
# 185667             1                   2748       1
# 185668            19                   8587       4
# 185669            19                   8587       4
# 185670            19                   8587       4
# 185671             1                   3540       4
# 185672             1                   3540       4
# 185673             1                   2748       1
# 185674             1                   2748       1
# 185675            19                   8587       4
# 185676            19                   8587       4
# 185677            19                   8587       4
# 185678            19                   8587       4
# 185679            19                   8587       4
# 185680            19                   8587       4
# 185681            19                   8587       4
# 185682            19                   8587       4
# 185683            19                   8587       4
# 185684            19                   3045       1
# 185685            19                   3045       1
# 185686            19                   3045       1
#
# [185687 rows x 9 columns]

# %% [markdown]
# # Spliting input features

# %%
X=xm.iloc[:,:-1]
X
# Out:
#         SOL ID  Branch  Region  STATE   EVENT  AKNOWLEDGE STATUS  \
# 0         1255     619       3     11       6               7872
# 1         1166    1383       2     17       8                434
# 2         1092      62       2      0       6               7872
# 3         1525     781       3     11       6               7872
# 4           11     893       1     15       6               7872
# 5          450     675       3     11      13               1994
# 6          713    1746       1     19       6               7872
# 7          943     607       3     11       6               7872
# 8           48     334       1      5       8               5356
# 9           48     334       1      5       5               5356
# 10        1711      80       2      0       7               5356
# 11         356     668       3     11       6               3237
# 12          26     442       2      9      13               5671
# 13        1127    1515       2     17       7               5326
# 14          26     442       2      9      13               1956
# 15         163     372       1      7      13               1980
# 16        1609     641       3     11       6               3237
# 17          62     901       1     15       8               5338
# 18         947     825       3     10       6               3237
# 19         770     129       1      1       8               5360
# 20         163     372       1      7      13               1980
# 21         891      41       2      0       6               3237
# 22         770     129       1      1       8               5360
# 23          18     895       1     15       6               3237
# 24         660     102       2      0       8               5360
# 25         660     102       2      0       5               5360
# 26        1127    1515       2     17       7               5449
# 27        1664     296       3      4       6               3237
# 28        1280     757       3     11       5               5387
# 29         566     222       3      4       8               5400
# ...        ...     ...     ...    ...     ...                ...
# 185657     705      16       3     16      10               2682
# 185658     705      16       3     16       5               2682
# 185659     705      16       3     16      12               2682
# 185660     705      16       3     16       5               2682
# 185661     705      16       3     16       5               2682
# 185662     705      16       3     16      12               2682
# 185663     807     882       0     13      10               2968
# 185664     807     882       0     13       5               2968
# 185665     807     882       0     13      12               2968
# 185666     436     341       1      5      12               3415
# 185667     705      16       3     16       5               2682
# 185668     833     884       0     13       9               8337
# 185669     833     884       0     13       5               8337
# 185670     833     884       0     13      12               8337
# 185671    1536    1074       3     16       5               3466
# 185672    1536    1074       3     16      12               3466
# 185673     705      16       3     16       9               2682
# 185674     705      16       3     16      12               2682
# 185675    1341    1107       3     16       9               8337
# 185676    1341    1107       3     16       5               8337
# 185677    1341    1107       3     16      12               8337
# 185678    1552     282       3      4       5               8337
# 185679    1552     282       3      4      12               8337
# 185680    1369    1022       3     16       5               8337
# 185681    1369    1022       3     16       9               8337
# 185682    1369    1022       3     16       5               8337
# 185683    1369    1022       3     16      12               8337
# 185684     807     882       0     13      10               2968
# 185685     807     882       0     13       5               2968
# 185686     807     882       0     13      12               2968
#
#         Confirmation  2nd AKNOWLEDGE STATUS
# 0                 14                   8079
# 1                 15                    442
# 2                 14                   8079
# 3                 14                   8079
# 4                 14                   8079
# 5                 12                   2070
# 6                 14                   8079
# 7                 14                   8079
# 8                 15                   5517
# 9                 15                   5517
# 10                15                   5517
# 11                14                   3313
# 12                26                   5864
# 13                12                   5487
# 14                26                   2031
# 15                12                   2055
# 16                14                   3313
# 17                15                   5499
# 18                14                   3313
# 19                12                   5522
# 20                12                   2055
# 21                14                   3313
# 22                12                   5522
# 23                14                   3313
# 24                12                   5522
# 25                12                   5522
# 26                12                   5616
# 27                14                   3313
# 28                19                   5552
# 29                26                   5565
# ...              ...                    ...
# 185657             1                   2748
# 185658             1                   2748
# 185659             1                   2748
# 185660             1                   2748
# 185661             1                   2748
# 185662             1                   2748
# 185663            19                   3045
# 185664            19                   3045
# 185665            19                   3045
# 185666             8                   3488
# 185667             1                   2748
# 185668            19                   8587
# 185669            19                   8587
# 185670            19                   8587
# 185671             1                   3540
# 185672             1                   3540
# 185673             1                   2748
# 185674             1                   2748
# 185675            19                   8587
# 185676            19                   8587
# 185677            19                   8587
# 185678            19                   8587
# 185679            19                   8587
# 185680            19                   8587
# 185681            19                   8587
# 185682            19                   8587
# 185683            19                   8587
# 185684            19                   3045
# 185685            19                   3045
# 185686            19                   3045
#
# [185687 rows x 8 columns]

# %% [markdown]
# # Output feature

# %%
y=xm.iloc[:,8]
y
# Out:
# 0         3
# 1         0
# 2         3
# 3         3
# 4         3
# 5         0
# 6         3
# 7         3
# 8         0
# 9         0
# 10        0
# 11        3
# 12        0
# 13        0
# 14        0
# 15        0
# 16        3
# 17        0
# 18        3
# 19        0
# 20        0
# 21        3
# 22        0
# 23        3
# 24        0
# 25        0
# 26        0
# 27        3
# 28        0
# 29        0
#          ..
# 185657    1
# 185658    1
# 185659    1
# 185660    1
# 185661    1
# 185662    1
# 185663    1
# 185664    1
# 185665    1
# 185666    4
# 185667    1
# 185668    4
# 185669    4
# 185670    4
# 185671    4
# 185672    4
# 185673    1
# 185674    1
# 185675    4
# 185676    4
# 185677    4
# 185678    4
# 185679    4
# 185680    4
# 185681    4
# 185682    4
# 185683    4
# 185684    1
# 185685    1
# 185686    1
# Name: Status, Length: 185687, dtype: int32

# %%
feature_names = X.columns.tolist()
feature_names
# Out:
# ['SOL ID',
#  'Branch',
#  'Region',
#  'STATE',
#  ' EVENT',
#  'AKNOWLEDGE STATUS',
#  'Confirmation',
#  '2nd AKNOWLEDGE STATUS']

# %% [markdown]
# Calculate the correlation with y for each feature and collect all correlation values in a list

# %%
list(map(lambda x: np.corrcoef(X[x], y)[0, 1], feature_names))
# Out:
# [0.013946352703390391,
#  0.03753497468627008,
#  0.023269297890477443,
#  0.04212299189733029,
#  0.040683411454082864,
#  0.2874322535455798,
#  0.10985699347995073,
#  0.30858414218626584]

# %%
cor_feature = X.iloc[:,np.argsort(np.abs(cor_list))[-3:]].columns.tolist()
cor_feature
# Out:
# ['Confirmation', 'AKNOWLEDGE STATUS', '2nd AKNOWLEDGE STATUS']

# %% [markdown]
# ## Create dataframes from Scores (cor_list) and Features

# %%
dfscores = pd.DataFrame(cor_list)
dfcolumns = pd.DataFrame(X.columns)

# %% [markdown]
# ## Which are the best features?

# %%
featurescores = pd.concat([dfcolumns,dfscores], axis=1)
featurescores
featurescores.columns = ['features','Scores']
featurescores
featurescores.nlargest(10, 'Scores')
# Out:
#                 features    Scores
# 7  2nd AKNOWLEDGE STATUS  0.308584
# 5      AKNOWLEDGE STATUS  0.287432
# 6           Confirmation  0.109857
# 3                  STATE  0.042123
# 4                  EVENT  0.040683
# 1                 Branch  0.037535
# 2                 Region  0.023269
# 0                 SOL ID  0.013946

# %% [markdown]
# # Split Train and Test data

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30, random_state=5)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (129980, 8)
# (55707, 8)
# (129980,)
# (55707,)

# %% [markdown]
# ## Building machine learing model

# %% [markdown]
# # 1. Logistic Regression

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

data = p

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30, random_state=5)


model = LogisticRegression()
model.fit(X_train, y_train)

print(model.score(X_test, y_test))
print(model.score(X_train, y_train))
# Out:
# 0.5982192543127435
# 0.5926219418372057

# %% [markdown]
# # 2. KNearest Neighbour

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_classifier = KNeighborsClassifier()
knn_classifier.fit(X_train, y_train)
knn_predictions = knn_classifier.predict(X_test)
print(knn_classifier.score(X_test, y_test))
# Out:
# 0.962123252015007

# %%
X_ = np.array([1255,619,3,11,6,7872,14,8079])
y_pred =knn_classifier.predict([X_])


X1 = np.array([705,16,3,16,10,2682,1,2748])
y_pred1 =knn_classifier.predict([X1])

print(y_pred)
print(y_pred1)
# Out:
# [3]
# [1]

# %% [markdown]
# # 3. Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf_classifier = RandomForestClassifier()
rf_classifier.fit(X_train, y_train)
rf_predictions = rf_classifier.predict(X_test)
print(rf_classifier.score(X_test, y_test))
# Out:
# 0.9804871919148401

# %%
X_ = np.array([1255,619,3,11,6,7872,14,8079])
y_pred =rf_classifier.predict([X_])
y_pred
# Out:
# array([3])

# %% [markdown]
# # Conclusion

# %%
print('\n                     Accuracy     Error')
print('                     ----------   --------')
print('Logistic Regression : {:.04}%       {:.04}%'.format( model.score(X_test, y_test)* 100,\
                                                  100-(model.score(X_test, y_test) * 100)))

print('KNN                 : {:.04}%       {:.04}% '.format(knn_classifier.score(X_test, y_test) * 100,\
                                                        100-(knn_classifier.score(X_test, y_test) * 100)))

print('Random Forest       : {:.04}%       {:.04}% '.format(rf_classifier.score(X_test, y_test)* 100,\
                                                           100-(rf_classifier.score(X_test, y_test)* 100)))
# Out:
#                      Accuracy     Error
#                      ----------   --------
# Logistic Regression : 59.82%       40.18%
# KNN                 : 96.21%       3.788%
# Random Forest       : 98.05%       1.951%

# %% [markdown]
# We can choose the Random Forest,KNN model to get the desired output

# %% [markdown]
# Happy learning.....
